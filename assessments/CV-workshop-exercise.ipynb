# %% [markdown]
# <img src="assessment.png">

# %% [markdown]
# # Assessment 1

# %% [markdown]
# The purpose of this assessment is to get better understanding on image processing which is the prior step of the training the machine learning model.
# #### Please finish your assessment before next sharing session.

# %% [markdown]
# ## How much do you know about panda?
#
#     The giant panda also known as the panda bear or simply the panda, is a bear native to south central China.  It is characterised by large, black patches around its eyes, over the ears, and across its round body.

# %% [markdown]
# This assessment will be performing on a cute sleeping panda image. Use the below image when you perform the image processing algorithms.
#
# <img src="sleeping_panda.jpg">

# %% [markdown]
# ### Let's get started !!

# %% [markdown]
# ### Import the necessary libraries to your program

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### The below code can be used to display image

# %%
def display_img(img,cmap=None):
    fig = plt.figure(figsize=(12,12))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap)

# %% [markdown]
# ### Task 1: Let's see how Cute the Sleeping Panda is.

# %% [markdown]
# <b> Hint: </b> Matplotlib expects the images in a different RGB ordering vs BGR in OpenCV.
# Please make sure the image is displayed in RGB color.
#
# Don't worry! OpenCV provides color converting function.

# %% [markdown]
# Don't you think the image size is too big to do image processing. Let's check its resolution it is.

# %% [markdown]
# ### Task 2: Check the image dimension and image shape.

# %% [markdown]
# ### Let's do Dimensionality Reduction to 50% of the original image.

# %% [markdown]
# Calculate new width and height of the original image by reducing 50% of the dimension.That can reduce the operation time on image processing.

# %%
original_height = img.shape[0]
original_width = img.shape[1]
scale_percent = 50

new_height = int(original_height * scale_percent / 100)
new_width = int(original_width * scale_percent / 100)

# %% [markdown]
# ### Task 3: Resize the image using new width and new height and display it.

# %% [markdown]
# I want the panda sleeping on the left side! Please make it FLIP!!

# %% [markdown]
# ### Task 4: Flip the resized image horizontally and display it.

# %% [markdown]
# <b> Hint: </b> OpenCV supports flipping both horizontally and vertically.

# %% [markdown]
# We better save the resized and flipped image to our directory with name <b> modified_img.jpg </b>

# %% [markdown]
# ### Task 5: Save modified image in the directory.

# %% [markdown]
# ### Task 5: Upload the recent saved panda image and do edge detection of Grayscale panda image

# %% [markdown]
# #### Task 5.1: Upload and covert into gray scale image

# %% [markdown]
# #### Task 5.2: Perform Edge Detection and display it.

# %%
np.shape(modified_img)
# Out:
# (600, 960, 3)

# %% [markdown]
# As we understand that blurring performs when the image has noises. The below function create the noises.

# %%
def generate_noise(img):
    white_noise = np.random.randint(low=0,high=2,size=(600,960,3))
    white_noise = white_noise*100
    noise_img = white_noise+img
    return noise_img

noise_img = generate_noise(modified_img)
display_img(noise_img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Save the noisy panda image again.

# %%
cv2.imwrite("noisy_image.jpg", noise_img)
# Out:
# True

# %% [markdown]
# ### Task 6: Upload and make 50% of the noisy panda image as blurr to reduce noise

# %% [markdown]
# <b> Hint: </b>Use all three mechanisms: GaussianBlur, MedianBlur, BilateralFilter for blurring the image.

# %%
#GaussianBlur

# %%
#MedianBlur

# %%
#BilateralFilter

# %% [markdown]
# ### Write the summarization on three blurring mechanisms. What do you think which one is better for this noisy image.

# %% [markdown]
# ## Yayy! You did GREAT !!

# %% [markdown]
# ### End of the Assessment.
